# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
iteration = pd.read_csv("./output/iterations.txt", sep='\t', index_col=0)

# %%
iteration
# Out:
#                  obj  reduced_cost
# iter_num
# 0         5391170.61    3927700.00
# 1         4813723.19    2688541.67
# 2         4512437.63    2426977.43
# 3         4362250.65    2145050.81
# 4         4326511.83    2196047.72
# ...              ...           ...
# 317       3439379.35        128.87
# 318       3439379.31        128.87
# 319       3439379.27        128.87
# 320       3439376.09        135.98
# 321       3439373.87         -0.00
#
# [322 rows x 2 columns]

# %%
import seaborn as sns
custom_params = {"axes.spines.right": False, "axes.spines.top": False}
sns.set_theme(style="ticks", rc=custom_params)
plt.rcParams["font.family"] = "Times New Roman"

# %%
plt.figure(figsize=(10, 5), dpi=300)
plt.subplot(121)
plt.plot(iteration["obj"])
plt.xlabel("Iteration Number")
plt.ylabel("Objective")
plt.subplot(122)
sns.lineplot(x=np.arange(200, iteration.shape[0]), y=iteration["obj"][200:])
plt.xlabel("Iteration Number")
plt.ylabel("")
# Out:
# Text(0, 0.5, '')

# %%
sensitivity = pd.read_csv("./output/sensitivity.txt", index_col=0, sep='\t')

# %%
sensitivity
# Out:
#              obj
# m
# 0   3.176000e+06
# 1   3.296681e+06
# 2   3.348257e+06
# 3   3.375719e+06
# 4   3.400896e+06
# 5   3.413609e+06
# 6   3.425322e+06
# 7   3.435217e+06
# 8   3.439063e+06
# 9   3.439374e+06
# 10  3.439374e+06
# 11  3.439374e+06
# 12  3.439374e+06
# 13  3.439374e+06
# 14  3.439374e+06

# %%
plt.figure(figsize=(5, 5), dpi=300)
plt.plot(sensitivity["obj"])
plt.xlabel("M")
plt.ylabel("Objective")
plt.grid(True)
